# %%
## Load packages and data
import pandas as pd
import numpy as np
from plotnine import *
from scipy import stats
from dateutil.relativedelta import relativedelta

import statsmodels.formula.api as sm
import statsmodels.stats.sandwich_covariance as sw
import statsmodels as statsmodels

# %store -r merged_date_cleaned_new
# %store -r bw_only
# %store -r mf_only

merged = merged_date_cleaned_new.copy()

# %%
## Function that:
# subsets data into bandwidths and creates indicator
# runs regression for target group
# compile regression results

def subset_data(df_input, cutoff, bw_length):
    cutoff = pd.to_datetime(cutoff)
    df_merged = df_input.copy()
    
    ## Set bandwidth range
    end = cutoff + relativedelta(days=+bw_length)
    start = cutoff + relativedelta(days=-bw_length)
    window_range = pd.date_range(start=start,end=end)
    
    ## Subset to within range
    df = df_merged[df_merged['date_reviewed'].isin(window_range) & ~(df_merged['date_reviewed']==cutoff)].copy()
    df['is_after'] = df['date_reviewed']>cutoff
    
    ## Create two dataframes to compare
    df_b = df[df['is_after']==False]['Local ID'].reset_index()
    df_a = df[df['is_after']==True]['Local ID'].reset_index()
    before_list = pd.DataFrame(df_b['Local ID'].unique())
    after_list = pd.DataFrame(df_a['Local ID'].unique())
    
    ## Merge to see which IDs are in both datasets
    print(before_list.shape) # Merge diagnostics
    print(after_list.shape)
    one_list = before_list.merge(after_list, how = "outer", indicator = True, left_on = 0, right_on = 0)
    print(one_list.shape)
    one_list = one_list[~(one_list['_merge']=="both")]
    print(one_list.shape) # Merge diagnostics

    ## Keep only the IDs in only one of the two sets (before or after) to avoid IDs in both impacting the results
    df_either = df[df['Local ID'].isin(one_list[0])].copy()
    df_either['is_after'] = df_either['date_reviewed']>cutoff
    
    ## Save for visualization
    df_either['bw'] = bw_length
    
    return(df_either)

# %%
def run_regression(subsetted_data, var_forreg):
    
    df = subsetted_data.copy()
    ## Save for visualization
    bw_length = df['bw'].iloc[0]
        
    ## Put together formula based on variable being passed in
    form = 'irrit_score ~ is_after + ' + var_forreg + ' + is_after*' + var_forreg
    
    ## Run OLS
    reg = sm.ols(formula=form, data=df).fit(use_t=True)
    
    ## Return both the result of the regression and the bandwidth for the visualization
    return(reg, bw_length)

# %%
def run_predict(reg, var_forreg):
    
    ## Use regression, not bandwidth length used for visualization, in the prediction
    reg_touse = reg[0]
    
    ## Create values for prediction
    xnew = pd.DataFrame({var_forreg: [True, False, True, False], 'is_after': [False, False, True, True]})
    
    ## Generate predicition
    pred = reg_touse.get_prediction(xnew)
    
    ## Create dataframe to get the mean and SE
    summarydf = pred.summary_frame()
    
    ## Merge dataframes for visualization
    print(summarydf.shape) # Merge diagnostics
    print(xnew.shape)
    summarydf['index'] = summarydf.reset_index().index
    xnew['index'] = xnew.reset_index().index
    pred_withinputs_df = summarydf.merge(xnew, on = 'index')
    print(pred_withinputs_df.shape) # Merge diagnostics
    
    ## Include the bandwidth returned by run_regression() for the visualization
    pred_withinputs_df['bw'] = reg[1]
    pred_withinputs_df['bw'] = pred_withinputs_df['bw'].astype("category")
    
    return(pred_withinputs_df)

# %%
## Look at these bandwidths of days before and after each event
bandwidths = [30, 60, 90]
covid_date = "03-11-2020"
gf_date = "05-25-2020"

# %%
## Race - COVID

subset_list_covid_race = [subset_data(bw_only, covid_date, bw) for bw in bandwidths]

reg_list_covid_race = [run_regression(sub, 'is_black') for sub in subset_list_covid_race]

pred_list_covid_race = [run_predict(reg, 'is_black') for reg in reg_list_covid_race]

## Compile dataframes for each regression for a visualization
viz_df_covid_race = pd.concat(pred_list_covid_race).reset_index()
print(viz_df_covid_race)
# Out:
# (260, 1)
# (269, 1)
# (529, 2)
# (529, 2)
# (559, 1)
# (370, 1)
# (925, 2)
# (921, 2)
# (886, 1)
# (550, 1)
# (1410, 2)
# (1384, 2)
# (4, 6)
# (4, 2)
# (4, 9)
# (4, 6)
# (4, 2)
# (4, 9)
# (4, 6)
# (4, 2)
# (4, 9)
#     level_0       mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0         0  14.820513  1.181013      12.500551      17.140475     -5.799761
# 1         1  17.766304  0.768941      16.255809      19.276799     -2.778648
# 2         2  16.223529  1.131338      14.001147      18.445911     -4.385994
# 3         3  18.076923  0.746938      16.609650      19.544196     -2.464896
# 4         0  14.587838  0.865862      12.888592      16.287084     -6.154101
# 5         1  17.540865  0.516455      16.527327      18.554404     -3.156183
# 6         2  16.326733  1.048139      14.269770      18.383695     -4.447570
# 7         3  17.899642  0.630634      16.662028      19.137255     -2.809590
# 8         0  15.483333  0.677142      14.155031      16.811636     -5.137471
# 9         1  17.345736  0.413053      16.535479      18.155994     -3.248188
# 10        2  16.889655  0.871167      15.180747      18.598563     -3.759160
# 11        3  17.844612  0.525169      16.814424      18.874799     -2.759138
#
#     obs_ci_upper  index  is_black  is_after  bw
# 0      35.440786      0      True     False  30
# 1      38.311256      1     False     False  30
# 2      36.833052      2      True      True  30
# 3      38.618743      3     False      True  30
# 4      35.329776      0      True     False  60
# 5      38.237914      1     False     False  60
# 6      37.101036      2      True      True  60
# 7      38.608873      3     False      True  60
# 8      36.104138      0      True     False  90
# 9      37.939661      1     False     False  90
# 10     37.538470      2      True      True  90
# 11     38.448361      3     False      True  90

# %%
## LaTeX for Overleaf
print(reg_list_covid_race[0][0].summary().as_latex())
print(reg_list_covid_race[1][0].summary().as_latex())
print(reg_list_covid_race[2][0].summary().as_latex())
# Out:
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}                      &   irrit\_score   & \textbf{  R-squared:         } &     0.012   \\
# \textbf{Model:}                              &       OLS        & \textbf{  Adj. R-squared:    } &     0.007   \\
# \textbf{Method:}                             &  Least Squares   & \textbf{  F-statistic:       } &     2.241   \\
# \textbf{Date:}                               & Mon, 14 Mar 2022 & \textbf{  Prob (F-statistic):} &   0.0825    \\
# \textbf{Time:}                               &     18:50:26     & \textbf{  Log-Likelihood:    } &   -2037.9   \\
# \textbf{No. Observations:}                   &         542      & \textbf{  AIC:               } &     4084.   \\
# \textbf{Df Residuals:}                       &         538      & \textbf{  BIC:               } &     4101.   \\
# \textbf{Df Model:}                           &           3      & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                                              & \textbf{coef} & \textbf{std err} & \textbf{t} & \textbf{P$> |$t$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{Intercept}                           &      17.7663  &        0.769     &    23.105  &         0.000        &       16.256    &       19.277     \\
# \textbf{is\_after[T.True]}                   &       0.3106  &        1.072     &     0.290  &         0.772        &       -1.795    &        2.416     \\
# \textbf{is\_black[T.True]}                   &      -2.9458  &        1.409     &    -2.090  &         0.037        &       -5.714    &       -0.177     \\
# \textbf{is\_after[T.True]:is\_black[T.True]} &       1.0924  &        1.955     &     0.559  &         0.577        &       -2.749    &        4.934     \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lclc}
# \textbf{Omnibus:}       & 38.589 & \textbf{  Durbin-Watson:     } &    1.818  \\
# \textbf{Prob(Omnibus):} &  0.000 & \textbf{  Jarque-Bera (JB):  } &   19.787  \\
# \textbf{Skew:}          &  0.291 & \textbf{  Prob(JB):          } & 5.05e-05  \\
# \textbf{Kurtosis:}      &  2.266 & \textbf{  Cond. No.          } &     6.45  \\
# \bottomrule
# \end{tabular}
# %\caption{OLS Regression Results}
# \end{center}
#
# Notes: \newline
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}                      &   irrit\_score   & \textbf{  R-squared:         } &     0.012   \\
# \textbf{Model:}                              &       OLS        & \textbf{  Adj. R-squared:    } &     0.009   \\
# \textbf{Method:}                             &  Least Squares   & \textbf{  F-statistic:       } &     3.760   \\
# \textbf{Date:}                               & Mon, 14 Mar 2022 & \textbf{  Prob (F-statistic):} &   0.0106    \\
# \textbf{Time:}                               &     18:50:26     & \textbf{  Log-Likelihood:    } &   -3560.2   \\
# \textbf{No. Observations:}                   &         944      & \textbf{  AIC:               } &     7128.   \\
# \textbf{Df Residuals:}                       &         940      & \textbf{  BIC:               } &     7148.   \\
# \textbf{Df Model:}                           &           3      & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                                              & \textbf{coef} & \textbf{std err} & \textbf{t} & \textbf{P$> |$t$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{Intercept}                           &      17.5409  &        0.516     &    33.964  &         0.000        &       16.527    &       18.554     \\
# \textbf{is\_after[T.True]}                   &       0.3588  &        0.815     &     0.440  &         0.660        &       -1.241    &        1.958     \\
# \textbf{is\_black[T.True]}                   &      -2.9530  &        1.008     &    -2.929  &         0.003        &       -4.932    &       -0.974     \\
# \textbf{is\_after[T.True]:is\_black[T.True]} &       1.3801  &        1.585     &     0.871  &         0.384        &       -1.731    &        4.491     \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lclc}
# \textbf{Omnibus:}       & 74.443 & \textbf{  Durbin-Watson:     } &    1.801  \\
# \textbf{Prob(Omnibus):} &  0.000 & \textbf{  Jarque-Bera (JB):  } &   33.583  \\
# \textbf{Skew:}          &  0.261 & \textbf{  Prob(JB):          } & 5.10e-08  \\
# \textbf{Kurtosis:}      &  2.238 & \textbf{  Cond. No.          } &     6.04  \\
# \bottomrule
# \end{tabular}
# %\caption{OLS Regression Results}
# \end{center}
#
# Notes: \newline
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}                      &   irrit\_score   & \textbf{  R-squared:         } &     0.006   \\
# \textbf{Model:}                              &       OLS        & \textbf{  Adj. R-squared:    } &     0.004   \\
# \textbf{Method:}                             &  Least Squares   & \textbf{  F-statistic:       } &     2.705   \\
# \textbf{Date:}                               & Mon, 14 Mar 2022 & \textbf{  Prob (F-statistic):} &   0.0441    \\
# \textbf{Time:}                               &     18:50:26     & \textbf{  Log-Likelihood:    } &   -5384.4   \\
# \textbf{No. Observations:}                   &        1429      & \textbf{  AIC:               } & 1.078e+04   \\
# \textbf{Df Residuals:}                       &        1425      & \textbf{  BIC:               } & 1.080e+04   \\
# \textbf{Df Model:}                           &           3      & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                                              & \textbf{coef} & \textbf{std err} & \textbf{t} & \textbf{P$> |$t$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{Intercept}                           &      17.3457  &        0.413     &    41.994  &         0.000        &       16.535    &       18.156     \\
# \textbf{is\_after[T.True]}                   &       0.4989  &        0.668     &     0.747  &         0.455        &       -0.812    &        1.810     \\
# \textbf{is\_black[T.True]}                   &      -1.8624  &        0.793     &    -2.348  &         0.019        &       -3.418    &       -0.306     \\
# \textbf{is\_after[T.True]:is\_black[T.True]} &       0.9074  &        1.290     &     0.703  &         0.482        &       -1.623    &        3.438     \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lclc}
# \textbf{Omnibus:}       & 131.552 & \textbf{  Durbin-Watson:     } &    1.768  \\
# \textbf{Prob(Omnibus):} &   0.000 & \textbf{  Jarque-Bera (JB):  } &   57.558  \\
# \textbf{Skew:}          &   0.293 & \textbf{  Prob(JB):          } & 3.17e-13  \\
# \textbf{Kurtosis:}      &   2.211 & \textbf{  Cond. No.          } &     5.97  \\
# \bottomrule
# \end{tabular}
# %\caption{OLS Regression Results}
# \end{center}
#
# Notes: \newline
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# %store viz_df_covid_race
# Out:
# Stored 'viz_df_covid_race' (DataFrame)

# %%
## Race - Death of George Floyd

subset_list_gf_race = [subset_data(bw_only, gf_date, bw) for bw in bandwidths]

reg_list_gf_race = [run_regression(sub, 'is_black') for sub in subset_list_gf_race]

pred_list_gf_race = [run_predict(reg, 'is_black') for reg in reg_list_gf_race]

## Compile dataframes for each regression for a visualization
viz_df_gf_race = pd.concat(pred_list_gf_race).reset_index()
print(viz_df_gf_race)
# Out:
# (114, 1)
# (190, 1)
# (304, 2)
# (304, 2)
# (312, 1)
# (381, 1)
# (692, 2)
# (691, 2)
# (615, 1)
# (582, 1)
# (1164, 2)
# (1131, 2)
# (4, 6)
# (4, 2)
# (4, 9)
# (4, 6)
# (4, 2)
# (4, 9)
# (4, 6)
# (4, 2)
# (4, 9)
#     level_0       mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0         0  16.538462  1.642430      13.306700      19.770223     -3.900993
# 1         1  18.037975  1.153999      15.767284      20.308666     -2.271704
# 2         2  15.536585  1.601870      12.384633      18.688538     -4.890402
# 3         3  18.428571  0.826530      16.802232      20.054911     -1.819194
# 4         0  17.688312  1.192146      15.347725      20.028899     -2.983191
# 5         1  18.024793  0.672461      16.704524      19.345062     -2.556164
# 6         2  17.022989  1.121541      14.821023      19.224954     -3.633278
# 7         3  18.596026  0.601965      17.414165      19.777888     -1.976516
# 8         0  16.420118  0.801323      14.847904      17.992332     -4.079045
# 9         1  17.971698  0.505904      16.979103      18.964293     -2.491173
# 10        2  17.112903  0.935492      15.277446      18.948360     -3.408129
# 11        3  18.431818  0.496620      17.457437      19.406199     -2.030177
#
#     obs_ci_upper  index  is_black  is_after  bw
# 0      36.977916      0      True     False  30
# 1      38.347653      1     False     False  30
# 2      35.963573      2      True      True  30
# 3      38.676336      3     False      True  30
# 4      38.359815      0      True     False  60
# 5      38.605751      1     False     False  60
# 6      37.679255      2      True      True  60
# 7      39.168569      3     False      True  60
# 8      36.919282      0      True     False  90
# 9      38.434569      1     False     False  90
# 10     37.633935      2      True      True  90
# 11     38.893814      3     False      True  90

# %%
## LaTeX for Overleaf
print(reg_list_gf_race[0][0].summary().as_latex())
print(reg_list_gf_race[1][0].summary().as_latex())
print(reg_list_gf_race[2][0].summary().as_latex())
# Out:
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}                      &   irrit\_score   & \textbf{  R-squared:         } &     0.010   \\
# \textbf{Model:}                              &       OLS        & \textbf{  Adj. R-squared:    } &     0.001   \\
# \textbf{Method:}                             &  Least Squares   & \textbf{  F-statistic:       } &     1.062   \\
# \textbf{Date:}                               & Mon, 14 Mar 2022 & \textbf{  Prob (F-statistic):} &    0.365    \\
# \textbf{Time:}                               &     18:50:35     & \textbf{  Log-Likelihood:    } &   -1170.8   \\
# \textbf{No. Observations:}                   &         313      & \textbf{  AIC:               } &     2350.   \\
# \textbf{Df Residuals:}                       &         309      & \textbf{  BIC:               } &     2365.   \\
# \textbf{Df Model:}                           &           3      & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                                              & \textbf{coef} & \textbf{std err} & \textbf{t} & \textbf{P$> |$t$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{Intercept}                           &      18.0380  &        1.154     &    15.631  &         0.000        &       15.767    &       20.309     \\
# \textbf{is\_after[T.True]}                   &       0.3906  &        1.419     &     0.275  &         0.783        &       -2.402    &        3.184     \\
# \textbf{is\_black[T.True]}                   &      -1.4995  &        2.007     &    -0.747  &         0.456        &       -5.449    &        2.450     \\
# \textbf{is\_after[T.True]:is\_black[T.True]} &      -1.3925  &        2.698     &    -0.516  &         0.606        &       -6.701    &        3.916     \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lclc}
# \textbf{Omnibus:}       & 27.262 & \textbf{  Durbin-Watson:     } &    1.778  \\
# \textbf{Prob(Omnibus):} &  0.000 & \textbf{  Jarque-Bera (JB):  } &   11.169  \\
# \textbf{Skew:}          &  0.220 & \textbf{  Prob(JB):          } &  0.00375  \\
# \textbf{Kurtosis:}      &  2.186 & \textbf{  Cond. No.          } &     7.18  \\
# \bottomrule
# \end{tabular}
# %\caption{OLS Regression Results}
# \end{center}
#
# Notes: \newline
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}                      &   irrit\_score   & \textbf{  R-squared:         } &     0.002   \\
# \textbf{Model:}                              &       OLS        & \textbf{  Adj. R-squared:    } &    -0.002   \\
# \textbf{Method:}                             &  Least Squares   & \textbf{  F-statistic:       } &    0.5775   \\
# \textbf{Date:}                               & Mon, 14 Mar 2022 & \textbf{  Prob (F-statistic):} &    0.630    \\
# \textbf{Time:}                               &     18:50:35     & \textbf{  Log-Likelihood:    } &   -2664.7   \\
# \textbf{No. Observations:}                   &         708      & \textbf{  AIC:               } &     5337.   \\
# \textbf{Df Residuals:}                       &         704      & \textbf{  BIC:               } &     5356.   \\
# \textbf{Df Model:}                           &           3      & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                                              & \textbf{coef} & \textbf{std err} & \textbf{t} & \textbf{P$> |$t$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{Intercept}                           &      18.0248  &        0.672     &    26.804  &         0.000        &       16.705    &       19.345     \\
# \textbf{is\_after[T.True]}                   &       0.5712  &        0.903     &     0.633  &         0.527        &       -1.201    &        2.343     \\
# \textbf{is\_black[T.True]}                   &      -0.3365  &        1.369     &    -0.246  &         0.806        &       -3.024    &        2.351     \\
# \textbf{is\_after[T.True]:is\_black[T.True]} &      -1.2366  &        1.869     &    -0.662  &         0.508        &       -4.906    &        2.433     \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lclc}
# \textbf{Omnibus:}       & 61.056 & \textbf{  Durbin-Watson:     } &    1.948  \\
# \textbf{Prob(Omnibus):} &  0.000 & \textbf{  Jarque-Bera (JB):  } &   23.929  \\
# \textbf{Skew:}          &  0.209 & \textbf{  Prob(JB):          } & 6.37e-06  \\
# \textbf{Kurtosis:}      &  2.202 & \textbf{  Cond. No.          } &     6.89  \\
# \bottomrule
# \end{tabular}
# %\caption{OLS Regression Results}
# \end{center}
#
# Notes: \newline
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}                      &   irrit\_score   & \textbf{  R-squared:         } &     0.005   \\
# \textbf{Model:}                              &       OLS        & \textbf{  Adj. R-squared:    } &     0.002   \\
# \textbf{Method:}                             &  Least Squares   & \textbf{  F-statistic:       } &     1.743   \\
# \textbf{Date:}                               & Mon, 14 Mar 2022 & \textbf{  Prob (F-statistic):} &    0.156    \\
# \textbf{Time:}                               &     18:50:35     & \textbf{  Log-Likelihood:    } &   -4351.1   \\
# \textbf{No. Observations:}                   &        1157      & \textbf{  AIC:               } &     8710.   \\
# \textbf{Df Residuals:}                       &        1153      & \textbf{  BIC:               } &     8730.   \\
# \textbf{Df Model:}                           &           3      & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                                              & \textbf{coef} & \textbf{std err} & \textbf{t} & \textbf{P$> |$t$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{Intercept}                           &      17.9717  &        0.506     &    35.524  &         0.000        &       16.979    &       18.964     \\
# \textbf{is\_after[T.True]}                   &       0.4601  &        0.709     &     0.649  &         0.516        &       -0.931    &        1.851     \\
# \textbf{is\_black[T.True]}                   &      -1.5516  &        0.948     &    -1.637  &         0.102        &       -3.411    &        0.308     \\
# \textbf{is\_after[T.True]:is\_black[T.True]} &       0.2327  &        1.421     &     0.164  &         0.870        &       -2.556    &        3.021     \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lclc}
# \textbf{Omnibus:}       & 88.132 & \textbf{  Durbin-Watson:     } &    1.854  \\
# \textbf{Prob(Omnibus):} &  0.000 & \textbf{  Jarque-Bera (JB):  } &   37.218  \\
# \textbf{Skew:}          &  0.219 & \textbf{  Prob(JB):          } & 8.29e-09  \\
# \textbf{Kurtosis:}      &  2.238 & \textbf{  Cond. No.          } &     6.35  \\
# \bottomrule
# \end{tabular}
# %\caption{OLS Regression Results}
# \end{center}
#
# Notes: \newline
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# %store viz_df_gf_race
# Out:
# Stored 'viz_df_gf_race' (DataFrame)

# %%
## Gender - COVID

subset_list_covid_gender = [subset_data(mf_only, covid_date, bw) for bw in bandwidths]

reg_list_covid_gender = [run_regression(sub, 'is_male') for sub in subset_list_covid_gender]

pred_list_covid_gender = [run_predict(reg, 'is_male') for reg in reg_list_covid_gender]

## Compile dataframes for each regression for a visualization
viz_df_covid_gender = pd.concat(pred_list_covid_gender).reset_index()
print(viz_df_covid_gender)
# Out:
# (407, 1)
# (391, 1)
# (798, 2)
# (798, 2)
# (814, 1)
# (541, 1)
# (1351, 2)
# (1347, 2)
# (1265, 1)
# (818, 1)
# (2047, 2)
# (2011, 2)
# (4, 6)
# (4, 2)
# (4, 9)
# (4, 6)
# (4, 2)
# (4, 9)
# (4, 6)
# (4, 2)
# (4, 9)
#     level_0       mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0         0  16.323194  0.644429      15.058249      17.588139     -4.229733
# 1         1  18.040541  0.859057      16.354303      19.726778     -2.542611
# 2         2  17.294545  0.630212      16.057507      18.531584     -3.256683
# 3         3  19.046512  0.920149      17.240358      20.852665     -1.546810
# 4         0  16.190647  0.445944      15.315843      17.065452     -4.455476
# 5         1  18.781481  0.639935      17.526127      20.036836     -1.884265
# 6         2  17.021108  0.540130      15.961540      18.080676     -3.633669
# 7         3  19.143678  0.797156      17.579905      20.707451     -1.543094
# 8         0  16.370499  0.357462      15.669477      17.071522     -4.211408
# 9         1  18.500000  0.520557      17.479130      19.520870     -2.095283
# 10        2  17.418773  0.445632      16.544838      18.292707     -3.169750
# 11        3  19.114625  0.659434      17.821402      20.407847     -1.495953
#
#     obs_ci_upper  index  is_male  is_after  bw
# 0      36.876121      0     True     False  30
# 1      38.623692      1    False     False  30
# 2      37.845774      2     True      True  30
# 3      39.639833      3    False      True  30
# 4      36.836771      0     True     False  60
# 5      39.447228      1    False     False  60
# 6      37.675886      2     True      True  60
# 7      39.830450      3    False      True  60
# 8      36.952407      0     True     False  90
# 9      39.095283      1    False     False  90
# 10     38.007295      2     True      True  90
# 11     39.725202      3    False      True  90

# %%
## LaTeX for Overleaf
print(reg_list_covid_gender[0][0].summary().as_latex())
print(reg_list_covid_gender[1][0].summary().as_latex())
print(reg_list_covid_gender[2][0].summary().as_latex())
# Out:
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}                     &   irrit\_score   & \textbf{  R-squared:         } &     0.008   \\
# \textbf{Model:}                             &       OLS        & \textbf{  Adj. R-squared:    } &     0.004   \\
# \textbf{Method:}                            &  Least Squares   & \textbf{  F-statistic:       } &     2.193   \\
# \textbf{Date:}                              & Mon, 14 Mar 2022 & \textbf{  Prob (F-statistic):} &   0.0875    \\
# \textbf{Time:}                              &     18:51:09     & \textbf{  Log-Likelihood:    } &   -3067.0   \\
# \textbf{No. Observations:}                  &         815      & \textbf{  AIC:               } &     6142.   \\
# \textbf{Df Residuals:}                      &         811      & \textbf{  BIC:               } &     6161.   \\
# \textbf{Df Model:}                          &           3      & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                                             & \textbf{coef} & \textbf{std err} & \textbf{t} & \textbf{P$> |$t$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{Intercept}                          &      18.0405  &        0.859     &    21.000  &         0.000        &       16.354    &       19.727     \\
# \textbf{is\_after[T.True]}                  &       1.0060  &        1.259     &     0.799  &         0.424        &       -1.465    &        3.477     \\
# \textbf{is\_male[T.True]}                   &      -1.7173  &        1.074     &    -1.599  &         0.110        &       -3.825    &        0.391     \\
# \textbf{is\_after[T.True]:is\_male[T.True]} &      -0.0346  &        1.548     &    -0.022  &         0.982        &       -3.074    &        3.004     \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lclc}
# \textbf{Omnibus:}       & 48.202 & \textbf{  Durbin-Watson:     } &    1.815  \\
# \textbf{Prob(Omnibus):} &  0.000 & \textbf{  Jarque-Bera (JB):  } &   30.473  \\
# \textbf{Skew:}          &  0.342 & \textbf{  Prob(JB):          } & 2.41e-07  \\
# \textbf{Kurtosis:}      &  2.345 & \textbf{  Cond. No.          } &     8.29  \\
# \bottomrule
# \end{tabular}
# %\caption{OLS Regression Results}
# \end{center}
#
# Notes: \newline
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}                     &   irrit\_score   & \textbf{  R-squared:         } &     0.012   \\
# \textbf{Model:}                             &       OLS        & \textbf{  Adj. R-squared:    } &     0.010   \\
# \textbf{Method:}                            &  Least Squares   & \textbf{  F-statistic:       } &     5.721   \\
# \textbf{Date:}                              & Mon, 14 Mar 2022 & \textbf{  Prob (F-statistic):} &  0.000686   \\
# \textbf{Time:}                              &     18:51:09     & \textbf{  Log-Likelihood:    } &   -5199.3   \\
# \textbf{No. Observations:}                  &        1379      & \textbf{  AIC:               } & 1.041e+04   \\
# \textbf{Df Residuals:}                      &        1375      & \textbf{  BIC:               } & 1.043e+04   \\
# \textbf{Df Model:}                          &           3      & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                                             & \textbf{coef} & \textbf{std err} & \textbf{t} & \textbf{P$> |$t$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{Intercept}                          &      18.7815  &        0.640     &    29.349  &         0.000        &       17.526    &       20.037     \\
# \textbf{is\_after[T.True]}                  &       0.3622  &        1.022     &     0.354  &         0.723        &       -1.643    &        2.368     \\
# \textbf{is\_male[T.True]}                   &      -2.5908  &        0.780     &    -3.322  &         0.001        &       -4.121    &       -1.061     \\
# \textbf{is\_after[T.True]:is\_male[T.True]} &       0.4683  &        1.239     &     0.378  &         0.706        &       -1.963    &        2.899     \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lclc}
# \textbf{Omnibus:}       & 100.581 & \textbf{  Durbin-Watson:     } &    1.834  \\
# \textbf{Prob(Omnibus):} &   0.000 & \textbf{  Jarque-Bera (JB):  } &   48.229  \\
# \textbf{Skew:}          &   0.273 & \textbf{  Prob(JB):          } & 3.37e-11  \\
# \textbf{Kurtosis:}      &   2.264 & \textbf{  Cond. No.          } &     8.07  \\
# \bottomrule
# \end{tabular}
# %\caption{OLS Regression Results}
# \end{center}
#
# Notes: \newline
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}                     &   irrit\_score   & \textbf{  R-squared:         } &     0.009   \\
# \textbf{Model:}                             &       OLS        & \textbf{  Adj. R-squared:    } &     0.008   \\
# \textbf{Method:}                            &  Least Squares   & \textbf{  F-statistic:       } &     6.507   \\
# \textbf{Date:}                              & Mon, 14 Mar 2022 & \textbf{  Prob (F-statistic):} &  0.000222   \\
# \textbf{Time:}                              &     18:51:09     & \textbf{  Log-Likelihood:    } &   -7815.4   \\
# \textbf{No. Observations:}                  &        2074      & \textbf{  AIC:               } & 1.564e+04   \\
# \textbf{Df Residuals:}                      &        2070      & \textbf{  BIC:               } & 1.566e+04   \\
# \textbf{Df Model:}                          &           3      & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                                             & \textbf{coef} & \textbf{std err} & \textbf{t} & \textbf{P$> |$t$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{Intercept}                          &      18.5000  &        0.521     &    35.539  &         0.000        &       17.479    &       19.521     \\
# \textbf{is\_after[T.True]}                  &       0.6146  &        0.840     &     0.732  &         0.465        &       -1.033    &        2.262     \\
# \textbf{is\_male[T.True]}                   &      -2.1295  &        0.631     &    -3.372  &         0.001        &       -3.368    &       -0.891     \\
# \textbf{is\_after[T.True]:is\_male[T.True]} &       0.4336  &        1.016     &     0.427  &         0.670        &       -1.559    &        2.426     \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lclc}
# \textbf{Omnibus:}       & 167.265 & \textbf{  Durbin-Watson:     } &    1.803  \\
# \textbf{Prob(Omnibus):} &   0.000 & \textbf{  Jarque-Bera (JB):  } &   78.801  \\
# \textbf{Skew:}          &   0.293 & \textbf{  Prob(JB):          } & 7.74e-18  \\
# \textbf{Kurtosis:}      &   2.246 & \textbf{  Cond. No.          } &     8.08  \\
# \bottomrule
# \end{tabular}
# %\caption{OLS Regression Results}
# \end{center}
#
# Notes: \newline
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# %store viz_df_covid_gender
# Out:
# Stored 'viz_df_covid_gender' (DataFrame)

# %%
## Gender - Death of George Floyd

subset_list_gf_gender = [subset_data(mf_only, gf_date, bw) for bw in bandwidths]

reg_list_gf_gender = [run_regression(sub, 'is_male') for sub in subset_list_gf_gender]

pred_list_gf_gender = [run_predict(reg, 'is_male') for reg in reg_list_gf_gender]

## Compile dataframes for each regression for a visualization
viz_df_gf_gender = pd.concat(pred_list_gf_gender).reset_index()
print(viz_df_gf_gender)
# Out:
# (186, 1)
# (298, 1)
# (484, 2)
# (484, 2)
# (468, 1)
# (577, 1)
# (1044, 2)
# (1043, 2)
# (920, 1)
# (881, 1)
# (1749, 2)
# (1697, 2)
# (4, 6)
# (4, 2)
# (4, 9)
# (4, 6)
# (4, 2)
# (4, 9)
# (4, 6)
# (4, 2)
# (4, 9)
#     level_0       mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0         0  18.328358  0.911873      16.536713      20.120003     -2.488677
# 1         1  17.879310  1.386030      15.156042      20.602578     -3.038509
# 2         2  17.968912  0.759815      16.476029      19.461795     -2.824541
# 3         3  17.846847  1.001902      15.878313      19.815381     -2.986158
# 4         0  17.904478  0.581584      16.763290      19.045665     -3.013830
# 5         1  19.384615  0.890158      17.637944      21.131287     -1.575445
# 6         2  18.160000  0.532237      17.115642      19.204358     -2.753248
# 7         3  19.731183  0.780510      18.199662      21.262703     -1.212046
# 8         0  17.291598  0.425342      16.457359      18.125837     -3.278790
# 9         1  19.021661  0.629640      17.786723      20.256599     -1.568871
# 10        2  17.685665  0.435505      16.831492      18.539838     -2.885541
# 11        3  19.638060  0.640125      18.382557      20.893562     -0.953715
#
#     obs_ci_upper  index  is_male  is_after  bw
# 0      39.145394      0     True     False  30
# 1      38.797130      1    False     False  30
# 2      38.762365      2     True      True  30
# 3      38.679852      3    False      True  30
# 4      38.822785      0     True     False  60
# 5      40.344676      1    False     False  60
# 6      39.073248      2     True      True  60
# 7      40.674412      3    False      True  60
# 8      37.861986      0     True     False  90
# 9      39.612192      1    False     False  90
# 10     38.256871      2     True      True  90
# 11     40.229835      3    False      True  90

# %%
## LaTeX for Overleaf
print(reg_list_gf_gender[0][0].summary().as_latex())
print(reg_list_gf_gender[1][0].summary().as_latex())
print(reg_list_gf_gender[2][0].summary().as_latex())
# Out:
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}                     &   irrit\_score   & \textbf{  R-squared:         } &     0.000   \\
# \textbf{Model:}                             &       OLS        & \textbf{  Adj. R-squared:    } &    -0.006   \\
# \textbf{Method:}                            &  Least Squares   & \textbf{  F-statistic:       } &   0.05291   \\
# \textbf{Date:}                              & Mon, 14 Mar 2022 & \textbf{  Prob (F-statistic):} &    0.984    \\
# \textbf{Time:}                              &     18:51:33     & \textbf{  Log-Likelihood:    } &   -1870.7   \\
# \textbf{No. Observations:}                  &         496      & \textbf{  AIC:               } &     3749.   \\
# \textbf{Df Residuals:}                      &         492      & \textbf{  BIC:               } &     3766.   \\
# \textbf{Df Model:}                          &           3      & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                                             & \textbf{coef} & \textbf{std err} & \textbf{t} & \textbf{P$> |$t$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{Intercept}                          &      17.8793  &        1.386     &    12.900  &         0.000        &       15.156    &       20.603     \\
# \textbf{is\_after[T.True]}                  &      -0.0325  &        1.710     &    -0.019  &         0.985        &       -3.393    &        3.328     \\
# \textbf{is\_male[T.True]}                   &       0.4490  &        1.659     &     0.271  &         0.787        &       -2.811    &        3.709     \\
# \textbf{is\_after[T.True]:is\_male[T.True]} &      -0.3270  &        2.082     &    -0.157  &         0.875        &       -4.417    &        3.763     \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lclc}
# \textbf{Omnibus:}       & 41.632 & \textbf{  Durbin-Watson:     } &    1.777  \\
# \textbf{Prob(Omnibus):} &  0.000 & \textbf{  Jarque-Bera (JB):  } &   18.368  \\
# \textbf{Skew:}          &  0.260 & \textbf{  Prob(JB):          } & 0.000103  \\
# \textbf{Kurtosis:}      &  2.214 & \textbf{  Cond. No.          } &     9.78  \\
# \bottomrule
# \end{tabular}
# %\caption{OLS Regression Results}
# \end{center}
#
# Notes: \newline
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}                     &   irrit\_score   & \textbf{  R-squared:         } &     0.005   \\
# \textbf{Model:}                             &       OLS        & \textbf{  Adj. R-squared:    } &     0.002   \\
# \textbf{Method:}                            &  Least Squares   & \textbf{  F-statistic:       } &     1.643   \\
# \textbf{Date:}                              & Mon, 14 Mar 2022 & \textbf{  Prob (F-statistic):} &    0.178    \\
# \textbf{Time:}                              &     18:51:33     & \textbf{  Log-Likelihood:    } &   -4024.2   \\
# \textbf{No. Observations:}                  &        1064      & \textbf{  AIC:               } &     8056.   \\
# \textbf{Df Residuals:}                      &        1060      & \textbf{  BIC:               } &     8076.   \\
# \textbf{Df Model:}                          &           3      & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                                             & \textbf{coef} & \textbf{std err} & \textbf{t} & \textbf{P$> |$t$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{Intercept}                          &      19.3846  &        0.890     &    21.777  &         0.000        &       17.638    &       21.131     \\
# \textbf{is\_after[T.True]}                  &       0.3466  &        1.184     &     0.293  &         0.770        &       -1.976    &        2.670     \\
# \textbf{is\_male[T.True]}                   &      -1.4801  &        1.063     &    -1.392  &         0.164        &       -3.567    &        0.606     \\
# \textbf{is\_after[T.True]:is\_male[T.True]} &      -0.0910  &        1.422     &    -0.064  &         0.949        &       -2.882    &        2.700     \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lclc}
# \textbf{Omnibus:}       & 80.152 & \textbf{  Durbin-Watson:     } &    1.867  \\
# \textbf{Prob(Omnibus):} &  0.000 & \textbf{  Jarque-Bera (JB):  } &   34.738  \\
# \textbf{Skew:}          &  0.229 & \textbf{  Prob(JB):          } & 2.86e-08  \\
# \textbf{Kurtosis:}      &  2.242 & \textbf{  Cond. No.          } &     9.32  \\
# \bottomrule
# \end{tabular}
# %\caption{OLS Regression Results}
# \end{center}
#
# Notes: \newline
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}                     &   irrit\_score   & \textbf{  R-squared:         } &     0.007   \\
# \textbf{Model:}                             &       OLS        & \textbf{  Adj. R-squared:    } &     0.005   \\
# \textbf{Method:}                            &  Least Squares   & \textbf{  F-statistic:       } &     4.137   \\
# \textbf{Date:}                              & Mon, 14 Mar 2022 & \textbf{  Prob (F-statistic):} &  0.00621    \\
# \textbf{Time:}                              &     18:51:33     & \textbf{  Log-Likelihood:    } &   -6521.0   \\
# \textbf{No. Observations:}                  &        1731      & \textbf{  AIC:               } & 1.305e+04   \\
# \textbf{Df Residuals:}                      &        1727      & \textbf{  BIC:               } & 1.307e+04   \\
# \textbf{Df Model:}                          &           3      & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                                             & \textbf{coef} & \textbf{std err} & \textbf{t} & \textbf{P$> |$t$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{Intercept}                          &      19.0217  &        0.630     &    30.210  &         0.000        &       17.787    &       20.257     \\
# \textbf{is\_after[T.True]}                  &       0.6164  &        0.898     &     0.686  &         0.492        &       -1.145    &        2.377     \\
# \textbf{is\_male[T.True]}                   &      -1.7301  &        0.760     &    -2.277  &         0.023        &       -3.220    &       -0.240     \\
# \textbf{is\_after[T.True]:is\_male[T.True]} &      -0.2223  &        1.085     &    -0.205  &         0.838        &       -2.350    &        1.905     \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lclc}
# \textbf{Omnibus:}       & 116.257 & \textbf{  Durbin-Watson:     } &    1.808  \\
# \textbf{Prob(Omnibus):} &   0.000 & \textbf{  Jarque-Bera (JB):  } &   55.360  \\
# \textbf{Skew:}          &   0.249 & \textbf{  Prob(JB):          } & 9.52e-13  \\
# \textbf{Kurtosis:}      &   2.279 & \textbf{  Cond. No.          } &     8.64  \\
# \bottomrule
# \end{tabular}
# %\caption{OLS Regression Results}
# \end{center}
#
# Notes: \newline
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# %store viz_df_gf_gender
# Out:
# Stored 'viz_df_gf_gender' (DataFrame)
